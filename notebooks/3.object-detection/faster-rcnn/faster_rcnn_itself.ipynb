# %%
import matplotlib.pyplot as plt
import numpy as np
import time
import cv2

# %% [markdown]
# ## The Summary of Faster RCNN

# %%
def faster_rcnn_summary(net, layer_type=False, layer_shape=False, 
                        get_flops=False, get_memory=False,
                        get_total_time=False, get_layer_time=False):
    # read the model
#     net = cv2.dnn.readNetFromCaffe(proto_path, model_path)
    
    # check if the model is empty
    if net.empty():
        print("Net is empty")
        return
        
    # get the types of layers used in the model
    if layer_type:
        print("Net contains:")
        for t in net.getLayerTypes():
            print("\t{} layers of type {}".format(net.getLayersCount(t), t))
    
    # get the tensor shapes for the loaded model and specified input shape
    if layer_shape:
        layers_ids, in_shapes, out_shapes = net.getLayersShapes([1, 3, 224, 224])
        layers_names = net.getLayerNames()
        print("Net layers shapes: ")
        for l in range(len(layers_names)):
            in_num, out_num = len(in_shapes[l]), len(out_shapes[l])
            print("  Layer {} has {} inputs and {} outputs".format(layers_names[l],
                                                                 in_num, out_num))
            for i in range(in_num):
                print("\tinput #{} has shape {}".format(i, in_shapes[l][i].flatten()))
            for i in range(out_num):
                print("\toutput #{} has shape {}".format(i, out_shapes[l][i].flatten()))
    
    # compute the number of FLOPs
    if get_flops:
        print("gflops: ", net.getFLOPS((1, 3, 224, 224)) * 1e-9)
    
    # report the amount of memory consumed for storing weights and intermediate tensors
    if get_memory:
        w, b = net.getMemoryConsumption((1, 3, 224, 224))
        print("weights (mb):", w * 1e-6, ", blobs (mb):", b * 1e-6)
    
    # perform a forward pass for a mock input:
    blob = cv2.dnn.blobFromImage(np.zeros((224, 224, 3), np.uint8), 1, (224, 224))
    net.setInput(blob)
    net.forward()
    
    # report the total time
    if get_total_time:
        total, timings = net.getPerfProfile()
        tick2ms = 1000 / cv2.getTickFrequency()
        print("inference (ms): {:2f}".format(total * tick2ms))

    # report the per layer inference time
    if get_layer_time:
        layer_names = net.getLayerNames()
        print("{: <30} {}".format("LAYER", "TIME (ms)"))
        for (i,t) in enumerate(timings):
            print("{: <30} {:.2f}".format(layer_names[i], t[0] * tick2ms))

# %%
model_path = "./model/frozen_inference_graph.pb"
proto_path = "./model/faster_rcnn_resnet50_coco_2018_01_28.pbtxt"

# %%
net = cv2.dnn.readNetFromTensorflow(model_path, proto_path)

# %%
faster_rcnn_summary(net, layer_type=True)
# Out:
# Net contains:
# 	56 layers of type Convolution
# 	1 layers of type CropAndResize
# 	2 layers of type DetectionOutput
# 	16 layers of type Eltwise
# 	4 layers of type Flatten
# 	2 layers of type InnerProduct
# 	3 layers of type Permute
# 	5 layers of type Pooling
# 	1 layers of type PriorBox
# 	49 layers of type ReLU
# 	2 layers of type ReLU6
# 	5 layers of type Reshape
# 	1 layers of type Scale
# 	1 layers of type Shift
# 	2 layers of type Slice
# 	2 layers of type Softmax
# 	1 layers of type __NetInputLayer__

# %%
faster_rcnn_summary(net, layer_shape=True)
# Out:
# Net layers shapes:
#   Layer Preprocessor/sub has 1 inputs and 1 outputs
# 	input #0 has shape [  1   3 224 224]
# 	output #0 has shape [  1   3 224 224]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1   3 224 224]
# 	output #0 has shape [  1   3 224 224]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1   3 224 224]
# 	output #0 has shape [  1  64 112 112]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/pool1/MaxPool has 1 inputs and 1 outputs
# 	input #0 has shape [  1  64 112 112]
# 	output #0 has shape [  1  64 112 112]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1  64 112 112]
# 	output #0 has shape [ 1 64 56 56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [  1 256  56  56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [  1 256  56  56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	input #1 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [  1 256  56  56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	input #1 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 28 28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 28 28]
# 	output #0 has shape [ 1 64 28 28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/shortcut/MaxPool has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 28 28]
# 	output #0 has shape [  1 256  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [  1 256  28  28]
# 	input #1 has shape [  1 256  28  28]
# 	output #0 has shape [  1 256  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  28  28]
# 	output #0 has shape [  1 256  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	input #1 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	input #1 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	input #1 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  14  14]
# 	output #0 has shape [  1 128  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/shortcut/MaxPool has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  14  14]
# 	output #0 has shape [  1 512  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [  1 512  14  14]
# 	input #1 has shape [  1 512  14  14]
# 	output #0 has shape [  1 512  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 512  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer Conv/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer Conv/Relu6 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 512  14  14]
#   Layer FirstStageBoxPredictor/ClassPredictor/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 512  14  14]
#   Layer FirstStageBoxPredictor/BoxEncodingPredictor/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [ 1 24 14 14]
#   Layer FirstStageBoxPredictor/ClassPredictor/reshape_1/nchw has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [ 1 48 14 14]
#   Layer FirstStageBoxPredictor/ClassPredictor/reshape_1 has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 24 14 14]
# 	output #0 has shape [ 1 14 14 24]
#   Layer FirstStageBoxPredictor/ClassPredictor/softmax has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 14 14 24]
# 	output #0 has shape [   1 2352    2]
#   Layer FirstStageBoxPredictor/ClassPredictor/softmax/flatten has 1 inputs and 1 outputs
# 	input #0 has shape [   1 2352    2]
# 	output #0 has shape [   1 2352    2]
#   Layer FirstStageBoxPredictor/BoxEncodingPredictor/flatten/nchw has 1 inputs and 1 outputs
# 	input #0 has shape [   1 2352    2]
# 	output #0 has shape [   1 4704]
#   Layer FirstStageBoxPredictor/BoxEncodingPredictor/flatten has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 48 14 14]
# 	output #0 has shape [ 1 14 14 48]
#   Layer proposals has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 14 14 48]
# 	output #0 has shape [   1 9408]
#   Layer detection_out has 2 inputs and 1 outputs
# 	input #0 has shape [ 1 48 14 14]
# 	input #1 has shape [  1   3 224 224]
# 	output #0 has shape [   1    2 9408]
#   Layer detection_out/clip_by_value has 3 inputs and 1 outputs
# 	input #0 has shape [   1 9408]
# 	input #1 has shape [   1 4704]
# 	input #2 has shape [   1    2 9408]
# 	output #0 has shape [  1   1 100   7]
#   Layer CropAndResize has 1 inputs and 1 outputs
# 	input #0 has shape [  1   1 100   7]
# 	output #0 has shape [  1   1 100   7]
#   Layer MaxPool2D/MaxPool has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [  1   1 100   7]
# 	output #0 has shape [ 100 1024   14   14]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [ 100 1024   14   14]
# 	output #0 has shape [ 100 1024    7    7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [ 100 1024    7    7]
# 	output #0 has shape [100 512   7   7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [100 512   7   7]
# 	output #0 has shape [100 512   7   7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [100 512   7   7]
# 	output #0 has shape [100 512   7   7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [100 512   7   7]
# 	output #0 has shape [100 512   7   7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [100 512   7   7]
# 	output #0 has shape [ 100 2048    7    7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [ 100 1024    7    7]
# 	output #0 has shape [ 100 2048    7    7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [ 100 2048    7    7]
# 	input #1 has shape [ 100 2048    7    7]
# 	output #0 has shape [ 100 2048    7    7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [ 100 2048    7    7]
# 	output #0 has shape [ 100 2048    7    7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [ 100 2048    7    7]
# 	output #0 has shape [100 512   7   7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [100 512   7   7]
# 	output #0 has shape [100 512   7   7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [100 512   7   7]
# 	output #0 has shape [100 512   7   7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [100 512   7   7]
# 	output #0 has shape [100 512   7   7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [100 512   7   7]
# 	output #0 has shape [ 100 2048    7    7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [ 100 2048    7    7]
# 	input #1 has shape [ 100 2048    7    7]
# 	output #0 has shape [ 100 2048    7    7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [ 100 2048    7    7]
# 	output #0 has shape [ 100 2048    7    7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [ 100 2048    7    7]
# 	output #0 has shape [100 512   7   7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [100 512   7   7]
# 	output #0 has shape [100 512   7   7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/Relu has 1 inputs and 1 outputs
# 	input #0 has shape [100 512   7   7]
# 	output #0 has shape [100 512   7   7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/Conv2D has 1 inputs and 1 outputs
# 	input #0 has shape [100 512   7   7]
# 	output #0 has shape [100 512   7   7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/add has 1 inputs and 1 outputs
# 	input #0 has shape [100 512   7   7]
# 	output #0 has shape [ 100 2048    7    7]
#   Layer SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/Relu has 2 inputs and 1 outputs
# 	input #0 has shape [ 100 2048    7    7]
# 	input #1 has shape [ 100 2048    7    7]
# 	output #0 has shape [ 100 2048    7    7]
#   Layer SecondStageBoxPredictor/AvgPool has 1 inputs and 1 outputs
# 	input #0 has shape [ 100 2048    7    7]
# 	output #0 has shape [ 100 2048    7    7]
#   Layer SecondStageBoxPredictor/Flatten/flatten/Reshape/nchw has 1 inputs and 1 outputs
# 	input #0 has shape [ 100 2048    7    7]
# 	output #0 has shape [ 100 2048    1    1]
#   Layer SecondStageBoxPredictor/Flatten/flatten/Reshape has 1 inputs and 1 outputs
# 	input #0 has shape [ 100 2048    1    1]
# 	output #0 has shape [ 100    1    1 2048]
#   Layer SecondStageBoxPredictor/ClassPredictor/MatMul has 1 inputs and 1 outputs
# 	input #0 has shape [ 100    1    1 2048]
# 	output #0 has shape [ 100 2048]
#   Layer SecondStageBoxPredictor/Reshape_1 has 1 inputs and 1 outputs
# 	input #0 has shape [ 100 2048]
# 	output #0 has shape [100  91]
#   Layer SecondStageBoxPredictor/BoxEncodingPredictor/MatMul has 1 inputs and 1 outputs
# 	input #0 has shape [100  91]
# 	output #0 has shape [100   1  91]
#   Layer SecondStageBoxPredictor/Reshape has 1 inputs and 1 outputs
# 	input #0 has shape [ 100 2048]
# 	output #0 has shape [100 360]
#   Layer SecondStageBoxPredictor/Reshape_1/softmax has 1 inputs and 1 outputs
# 	input #0 has shape [100 360]
# 	output #0 has shape [   1 9000    4]
#   Layer SecondStageBoxPredictor/Reshape_1/slice has 1 inputs and 1 outputs
# 	input #0 has shape [100   1  91]
# 	output #0 has shape [100   1  91]
#   Layer SecondStageBoxPredictor/Reshape_1/Reshape has 1 inputs and 1 outputs
# 	input #0 has shape [100   1  91]
# 	output #0 has shape [100   1  90]
#   Layer detection_out/slice has 1 inputs and 1 outputs
# 	input #0 has shape [100   1  90]
# 	output #0 has shape [   1 9000]
#   Layer variance_encoded has 1 inputs and 1 outputs
# 	input #0 has shape [  1   1 100   7]
# 	output #0 has shape [  1   1 100   4]
#   Layer detection_out/slice/reshape has 1 inputs and 1 outputs
# 	input #0 has shape [   1 9000    4]
# 	output #0 has shape [   1 9000    4]
#   Layer variance_encoded/flatten has 1 inputs and 1 outputs
# 	input #0 has shape [  1   1 100   4]
# 	output #0 has shape [  1   1 400]
#   Layer detection_out_final has 1 inputs and 1 outputs
# 	input #0 has shape [   1 9000    4]
# 	output #0 has shape [    1 36000]

# %%
faster_rcnn_summary(net, get_flops=True, get_memory=True)
# Out:
# gflops:  154.542609992
# weights (mb): 116.64647199999999 , blobs (mb): 712.595872

# %%
faster_rcnn_summary(net, get_total_time=True, get_layer_time=True)
# Out:
# inference (ms): 12268.492365
# LAYER                          TIME (ms)
# Preprocessor/sub               0.26
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/conv1/Conv2D 38.35
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/pool1/MaxPool 5.17
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/Conv2D 5.17
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/Conv2D 40.58
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/conv3/Conv2D 16.46
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/shortcut/Conv2D 24.35
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/add 7.71
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_1/bottleneck_v1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/Conv2D 11.41
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/Conv2D 36.17
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/conv3/Conv2D 9.86
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/add 3.18
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_2/bottleneck_v1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/Conv2D 12.42
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/Conv2D 6.28
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/conv3/Conv2D 4.23
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/shortcut/MaxPool 3.18
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/add 1.13
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block1/unit_3/bottleneck_v1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/Conv2D 8.38
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/Conv2D 29.59
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/conv3/Conv2D 15.40
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/shortcut/Conv2D 38.36
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/add 1.65
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_1/bottleneck_v1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/Conv2D 9.84
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/Conv2D 28.17
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/conv3/Conv2D 10.43
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/add 2.68
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_2/bottleneck_v1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/Conv2D 10.09
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/Conv2D 38.10
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/conv3/Conv2D 9.62
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/add 1.67
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_3/bottleneck_v1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/Conv2D 9.38
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/Conv2D 5.61
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/conv3/Conv2D 2.42
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/shortcut/MaxPool 3.66
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/add 1.60
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block2/unit_4/bottleneck_v1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/Conv2D 8.03
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/Conv2D 20.01
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/conv3/Conv2D 9.23
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/shortcut/Conv2D 19.28
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/add 1.32
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_1/bottleneck_v1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/Conv2D 10.58
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/Conv2D 19.46
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/conv3/Conv2D 9.51
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/add 0.96
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_2/bottleneck_v1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/Conv2D 10.38
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/Conv2D 20.25
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/conv3/Conv2D 9.35
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/add 1.01
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_3/bottleneck_v1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/Conv2D 9.77
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/Conv2D 21.54
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/conv3/Conv2D 11.73
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/add 1.04
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_4/bottleneck_v1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/Conv2D 10.64
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/Conv2D 28.47
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/conv3/Conv2D 12.18
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/add 1.02
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_5/bottleneck_v1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/Conv2D 9.57
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/conv1/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/Conv2D 20.92
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/conv2/Relu 0.00
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/conv3/Conv2D 9.67
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/add 1.06
# FirstStageFeatureExtractor/resnet_v1_50/resnet_v1_50/block3/unit_6/bottleneck_v1/Relu 0.00
# Conv/Conv2D                    150.51
# Conv/Relu6                     0.00
# FirstStageBoxPredictor/ClassPredictor/Conv2D 2.02
# FirstStageBoxPredictor/BoxEncodingPredictor/Conv2D 1.14
# FirstStageBoxPredictor/ClassPredictor/reshape_1/nchw 0.04
# FirstStageBoxPredictor/ClassPredictor/reshape_1 0.01
# FirstStageBoxPredictor/ClassPredictor/softmax 0.42
# FirstStageBoxPredictor/ClassPredictor/softmax/flatten 0.01
# FirstStageBoxPredictor/BoxEncodingPredictor/flatten/nchw 0.03
# FirstStageBoxPredictor/BoxEncodingPredictor/flatten 0.01
# proposals                      0.24
# detection_out                  23.30
# detection_out/clip_by_value    0.06
# CropAndResize                  372.36
# MaxPool2D/MaxPool              259.19
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/Conv2D 447.23
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/conv1/Relu 0.00
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/Conv2D 1782.73
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/conv2/Relu 0.00
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/conv3/Conv2D 641.23
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/shortcut/Conv2D 1172.00
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/add 24.92
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_1/bottleneck_v1/Relu 0.00
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/Conv2D 699.59
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/conv1/Relu 0.00
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/Conv2D 2033.06
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/conv2/Relu 0.00
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/conv3/Conv2D 886.13
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/add 28.08
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_2/bottleneck_v1/Relu 0.00
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/Conv2D 839.95
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/conv1/Relu 0.00
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/Conv2D 1387.04
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/conv2/Relu 0.00
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/conv3/Conv2D 706.72
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/add 23.60
# SecondStageFeatureExtractor/resnet_v1_50/block4/unit_3/bottleneck_v1/Relu 0.00
# SecondStageBoxPredictor/AvgPool 21.28
# SecondStageBoxPredictor/Flatten/flatten/Reshape/nchw 0.29
# SecondStageBoxPredictor/Flatten/flatten/Reshape 0.01
# SecondStageBoxPredictor/ClassPredictor/MatMul 2.91
# SecondStageBoxPredictor/Reshape_1 0.01
# SecondStageBoxPredictor/BoxEncodingPredictor/MatMul 14.18
# SecondStageBoxPredictor/Reshape 0.01
# SecondStageBoxPredictor/Reshape_1/softmax 0.28
# SecondStageBoxPredictor/Reshape_1/slice 0.02
# SecondStageBoxPredictor/Reshape_1/Reshape 0.00
# detection_out/slice            0.01
# variance_encoded               6.07
# detection_out/slice/reshape    0.01
# variance_encoded/flatten       0.00
# detection_out_final            12.26
