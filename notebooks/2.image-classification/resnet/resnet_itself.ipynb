# %%
import numpy as np
import cv2

# %%
def resnet152_v2_summary(net, layer_type=False, layer_shape=False, 
                         get_flops=False, get_memory=False,
                         get_total_time=False, get_layer_time=False):
    # check if the model is empty
    if net.empty():
        print("Net is empty")
        return
        
    # get the types of layers used in the model
    if layer_type:
        print("\nNet contains:")
        for t in net.getLayerTypes():
            print("\t{} layers of type {}".format(net.getLayersCount(t), t))
        
    
    
    # get the tensor shapes for the loaded model and specified input shape
    if layer_shape:
        layers_ids, in_shapes, out_shapes = net.getLayersShapes([1, 3, 224, 224])
        layers_names = net.getLayerNames()
        print("\nNet layers shapes: ")
        for l in range(len(layers_names)):
            in_num, out_num = len(in_shapes[l]), len(out_shapes[l])
            print("  Layer {} has {} inputs and {} outputs".format(layers_names[l],
                                                                 in_num, out_num))
            for i in range(in_num):
                print("\tinput #{} has shape {}".format(i, in_shapes[l][i].flatten()))
            for i in range(out_num):
                print("\toutput #{} has shape {}".format(i, out_shapes[l][i].flatten()))
            
    # compute the number of FLOPs
    if get_flops:
        print("\ngflops: ", net.getFLOPS((1, 3, 224, 224)) * 1e-9)
    
    # report the amount of memory consumed for storing weights and intermediate tensors
    if get_memory:
        w, b = net.getMemoryConsumption((1, 3, 224, 224))
        print("\nweights (mb):", w * 1e-6, ", blobs (mb):", b * 1e-6)
    
    # perform a forward pass for a mock input
    blob = cv2.dnn.blobFromImage(np.zeros((224, 224, 3), np.uint8), 1, (224, 224))
    net.setInput(blob)
    net.forward()
    
    # report the total time
    if get_total_time:
        total, timings = net.getPerfProfile()
        tick2ms = 1000 / cv2.getTickFrequency()
        print("\ninference (ms): {:2f}".format(total * tick2ms))
    
    # report the per layer inference time
    if get_layer_time:
        layer_names = net.getLayerNames()
        print("\n{: <30} {}".format("LAYER", "TIME (ms)"))
        for (i,t) in enumerate(timings):
            print("{: <30} {:.2f}".format(layer_names[i], t[0] * tick2ms))

# %%
model_path = "./model/resnet152v2.onnx"
resnet = cv2.dnn.readNetFromONNX(model_path)

# %%
resnet152_v2_summary(resnet, layer_type=True)
# Out:
# Net contains:
# 	153 layers of type BatchNorm
# 	155 layers of type Convolution
# 	50 layers of type Eltwise
# 	1 layers of type InnerProduct
# 	2 layers of type Pooling
# 	152 layers of type Relu
# 	1 layers of type Reshape
# 	1 layers of type __NetInputLayer__

# %%
resnet152_v2_summary(resnet, layer_shape=True)
# Out:
# Net layers shapes:
#   Layer resnetv27_batchnorm0_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1   3 224 224]
# 	output #0 has shape [  1   3 224 224]
#   Layer resnetv27_conv0_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1   3 224 224]
# 	output #0 has shape [  1   3 224 224]
#   Layer resnetv27_batchnorm1_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1   3 224 224]
# 	output #0 has shape [  1  64 112 112]
#   Layer resnetv27_relu0_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1  64 112 112]
# 	output #0 has shape [  1  64 112 112]
#   Layer resnetv27_pool0_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1  64 112 112]
# 	output #0 has shape [  1  64 112 112]
#   Layer resnetv27_stage1_batchnorm0_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1  64 112 112]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_activation0 has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_conv0_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_batchnorm1_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_activation1 has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_conv1_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_batchnorm2_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_activation2 has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_conv2_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_conv3_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage1__plus0 has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage1_batchnorm3_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	input #1 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage1_activation3 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage1_conv4_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage1_batchnorm4_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_activation4 has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_conv5_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_batchnorm5_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_activation5 has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_conv6_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1__plus1 has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage1_batchnorm6_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	input #1 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage1_activation6 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage1_conv7_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage1_batchnorm7_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_activation7 has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_conv8_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_batchnorm8_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_activation8 has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1_conv9_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
#   Layer resnetv27_stage1__plus2 has 1 inputs and 1 outputs
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage2_batchnorm0_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	input #1 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage2_activation0 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage2_conv0_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [  1 256  56  56]
#   Layer resnetv27_stage2_batchnorm1_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [  1 128  56  56]
#   Layer resnetv27_stage2_activation1 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  56  56]
# 	output #0 has shape [  1 128  56  56]
#   Layer resnetv27_stage2_conv1_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  56  56]
# 	output #0 has shape [  1 128  56  56]
#   Layer resnetv27_stage2_batchnorm2_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  56  56]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation2 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv2_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv3_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2__plus0 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  56  56]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm3_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	input #1 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_activation3 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_conv4_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm4_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation4 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv5_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_batchnorm5_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation5 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv6_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2__plus1 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm6_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	input #1 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_activation6 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_conv7_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm7_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation7 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv8_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_batchnorm8_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation8 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv9_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2__plus2 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm9_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	input #1 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_activation9 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_conv10_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm10_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation10 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv11_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_batchnorm11_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation11 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv12_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2__plus3 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm12_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	input #1 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_activation12 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_conv13_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm13_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation13 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv14_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_batchnorm14_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation14 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv15_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2__plus4 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm15_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	input #1 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_activation15 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_conv16_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm16_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation16 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv17_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_batchnorm17_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation17 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv18_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2__plus5 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm18_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	input #1 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_activation18 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_conv19_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm19_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation19 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv20_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_batchnorm20_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation20 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv21_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2__plus6 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm21_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	input #1 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_activation21 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_conv22_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage2_batchnorm22_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation22 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv23_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_batchnorm23_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_activation23 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2_conv24_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
#   Layer resnetv27_stage2__plus7 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage3_batchnorm0_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	input #1 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage3_activation0 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage3_conv0_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 512  28  28]
#   Layer resnetv27_stage3_batchnorm1_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [  1 256  28  28]
#   Layer resnetv27_stage3_activation1 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  28  28]
# 	output #0 has shape [  1 256  28  28]
#   Layer resnetv27_stage3_conv1_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  28  28]
# 	output #0 has shape [  1 256  28  28]
#   Layer resnetv27_stage3_batchnorm2_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  28  28]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation2 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv2_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv3_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3__plus0 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  28  28]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm3_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation3 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv4_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm4_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation4 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv5_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm5_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation5 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv6_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus1 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm6_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation6 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv7_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm7_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation7 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv8_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm8_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation8 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv9_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus2 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm9_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation9 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv10_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm10_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation10 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv11_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm11_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation11 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv12_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus3 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm12_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation12 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv13_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm13_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation13 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv14_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm14_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation14 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv15_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus4 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm15_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation15 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv16_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm16_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation16 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv17_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm17_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation17 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv18_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus5 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm18_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation18 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv19_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm19_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation19 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv20_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm20_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation20 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv21_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus6 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm21_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation21 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv22_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm22_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation22 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv23_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm23_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation23 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv24_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus7 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm24_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation24 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv25_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm25_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation25 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv26_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm26_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation26 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv27_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus8 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm27_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation27 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv28_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm28_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation28 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv29_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm29_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation29 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv30_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus9 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm30_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation30 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv31_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm31_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation31 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv32_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm32_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation32 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv33_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus10 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm33_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation33 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv34_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm34_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation34 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv35_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm35_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation35 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv36_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus11 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm36_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation36 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv37_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm37_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation37 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv38_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm38_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation38 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv39_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus12 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm39_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation39 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv40_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm40_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation40 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv41_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm41_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation41 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv42_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus13 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm42_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation42 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv43_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm43_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation43 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv44_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm44_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation44 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv45_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus14 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm45_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation45 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv46_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm46_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation46 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv47_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm47_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation47 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv48_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus15 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm48_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation48 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv49_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm49_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation49 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv50_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm50_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation50 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv51_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus16 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm51_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation51 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv52_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm52_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation52 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv53_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm53_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation53 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv54_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus17 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm54_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation54 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv55_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm55_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation55 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv56_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm56_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation56 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv57_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus18 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm57_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation57 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv58_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm58_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation58 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv59_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm59_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation59 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv60_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus19 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm60_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation60 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv61_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm61_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation61 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv62_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm62_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation62 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv63_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
# ...
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus28 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm87_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation87 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv88_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm88_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation88 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv89_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm89_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation89 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv90_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus29 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm90_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation90 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv91_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm91_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation91 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv92_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm92_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation92 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv93_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus30 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm93_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation93 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv94_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm94_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation94 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv95_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm95_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation95 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv96_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus31 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm96_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation96 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv97_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm97_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation97 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv98_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm98_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation98 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv99_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus32 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm99_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation99 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv100_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm100_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation100 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv101_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm101_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation101 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv102_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus33 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm102_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation102 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv103_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm103_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation103 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv104_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm104_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation104 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv105_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus34 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm105_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_activation105 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_conv106_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage3_batchnorm106_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation106 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv107_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_batchnorm107_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_activation107 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3_conv108_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
#   Layer resnetv27_stage3__plus35 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage4_batchnorm0_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	input #1 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage4_activation0 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage4_conv0_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 1024   14   14]
#   Layer resnetv27_stage4_batchnorm1_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [  1 512  14  14]
#   Layer resnetv27_stage4_activation1 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 512  14  14]
#   Layer resnetv27_stage4_conv1_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 512  14  14]
#   Layer resnetv27_stage4_batchnorm2_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_activation2 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_conv2_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_conv3_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_stage4__plus0 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 1024   14   14]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_stage4_batchnorm3_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 2048    7    7]
# 	input #1 has shape [   1 2048    7    7]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_stage4_activation3 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 2048    7    7]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_stage4_conv4_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 2048    7    7]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_stage4_batchnorm4_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 2048    7    7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_activation4 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_conv5_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_batchnorm5_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_activation5 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_conv6_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4__plus1 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_stage4_batchnorm6_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 2048    7    7]
# 	input #1 has shape [   1 2048    7    7]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_stage4_activation6 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 2048    7    7]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_stage4_conv7_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 2048    7    7]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_stage4_batchnorm7_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 2048    7    7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_activation7 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_conv8_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_batchnorm8_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_activation8 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4_conv9_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [  1 512   7   7]
#   Layer resnetv27_stage4__plus2 has 1 inputs and 1 outputs
# 	input #0 has shape [  1 512   7   7]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_batchnorm2_fwd has 2 inputs and 1 outputs
# 	input #0 has shape [   1 2048    7    7]
# 	input #1 has shape [   1 2048    7    7]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_relu1_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 2048    7    7]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_pool1_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 2048    7    7]
# 	output #0 has shape [   1 2048    7    7]
#   Layer resnetv27_flatten0_reshape0 has 1 inputs and 1 outputs
# 	input #0 has shape [   1 2048    7    7]
# 	output #0 has shape [   1 2048    1    1]
#   Layer resnetv27_dense0_fwd has 1 inputs and 1 outputs
# 	input #0 has shape [   1 2048    1    1]
# 	output #0 has shape [   1 2048]

# %%
resnet152_v2_summary(resnet, get_flops=True, get_memory=True)
# Out:
# gflops:  23.165506048
#
# weights (mb): 241.31655999999998 , blobs (mb): 314.824608

# %%
resnet152_v2_summary(resnet, get_total_time=True, get_layer_time=True)
# Out:
# inference (ms): 2863.795958
#
# LAYER                          TIME (ms)
# resnetv27_batchnorm0_fwd       0.22
# resnetv27_conv0_fwd            60.13
# resnetv27_batchnorm1_fwd       0.00
# resnetv27_relu0_fwd            0.00
# resnetv27_pool0_fwd            2.66
# resnetv27_stage1_batchnorm0_fwd 0.17
# resnetv27_stage1_activation0   0.11
# resnetv27_stage1_conv0_fwd     6.50
# resnetv27_stage1_batchnorm1_fwd 0.00
# resnetv27_stage1_activation1   0.00
# resnetv27_stage1_conv1_fwd     17.19
# resnetv27_stage1_batchnorm2_fwd 0.00
# resnetv27_stage1_activation2   0.00
# resnetv27_stage1_conv2_fwd     5.26
# resnetv27_stage1_conv3_fwd     13.36
# resnetv27_stage1__plus0        1.71
# resnetv27_stage1_batchnorm3_fwd 1.31
# resnetv27_stage1_activation3   0.89
# resnetv27_stage1_conv4_fwd     9.84
# resnetv27_stage1_batchnorm4_fwd 0.00
# resnetv27_stage1_activation4   0.00
# resnetv27_stage1_conv5_fwd     47.45
# resnetv27_stage1_batchnorm5_fwd 0.00
# resnetv27_stage1_activation5   0.00
# resnetv27_stage1_conv6_fwd     6.99
# resnetv27_stage1__plus1        1.85
# resnetv27_stage1_batchnorm6_fwd 1.26
# resnetv27_stage1_activation6   0.72
# resnetv27_stage1_conv7_fwd     7.55
# resnetv27_stage1_batchnorm7_fwd 0.00
# resnetv27_stage1_activation7   0.00
# resnetv27_stage1_conv8_fwd     15.19
# resnetv27_stage1_batchnorm8_fwd 0.00
# resnetv27_stage1_activation8   0.00
# resnetv27_stage1_conv9_fwd     6.87
# resnetv27_stage1__plus2        2.40
# resnetv27_stage2_batchnorm0_fwd 0.00
# resnetv27_stage2_activation0   0.71
# resnetv27_stage2_conv0_fwd     53.05
# resnetv27_stage2_batchnorm1_fwd 0.00
# resnetv27_stage2_activation1   0.00
# resnetv27_stage2_conv1_fwd     48.28
# resnetv27_stage2_batchnorm2_fwd 0.00
# resnetv27_stage2_activation2   0.00
# resnetv27_stage2_conv2_fwd     11.60
# resnetv27_stage2_conv3_fwd     11.83
# resnetv27_stage2__plus0        2.01
# resnetv27_stage2_batchnorm3_fwd 0.98
# resnetv27_stage2_activation3   1.19
# resnetv27_stage2_conv4_fwd     10.17
# resnetv27_stage2_batchnorm4_fwd 0.00
# resnetv27_stage2_activation4   0.00
# resnetv27_stage2_conv5_fwd     15.42
# resnetv27_stage2_batchnorm5_fwd 0.00
# resnetv27_stage2_activation5   0.00
# resnetv27_stage2_conv6_fwd     5.94
# resnetv27_stage2__plus1        1.26
# resnetv27_stage2_batchnorm6_fwd 0.87
# resnetv27_stage2_activation6   0.62
# resnetv27_stage2_conv7_fwd     9.25
# resnetv27_stage2_batchnorm7_fwd 0.00
# resnetv27_stage2_activation7   0.00
# resnetv27_stage2_conv8_fwd     14.51
# resnetv27_stage2_batchnorm8_fwd 0.00
# resnetv27_stage2_activation8   0.00
# resnetv27_stage2_conv9_fwd     11.10
# resnetv27_stage2__plus2        3.40
# resnetv27_stage2_batchnorm9_fwd 0.65
# resnetv27_stage2_activation9   0.35
# resnetv27_stage2_conv10_fwd    45.58
# resnetv27_stage2_batchnorm10_fwd 0.00
# resnetv27_stage2_activation10  0.00
# resnetv27_stage2_conv11_fwd    12.59
# resnetv27_stage2_batchnorm11_fwd 0.00
# resnetv27_stage2_activation11  0.00
# resnetv27_stage2_conv12_fwd    10.78
# resnetv27_stage2__plus3        1.01
# resnetv27_stage2_batchnorm12_fwd 0.70
# resnetv27_stage2_activation12  0.76
# resnetv27_stage2_conv13_fwd    7.53
# resnetv27_stage2_batchnorm13_fwd 0.00
# resnetv27_stage2_activation13  0.00
# resnetv27_stage2_conv14_fwd    14.78
# resnetv27_stage2_batchnorm14_fwd 0.00
# resnetv27_stage2_activation14  0.00
# resnetv27_stage2_conv15_fwd    54.79
# resnetv27_stage2__plus4        10.53
# resnetv27_stage2_batchnorm15_fwd 2.56
# resnetv27_stage2_activation15  2.36
# resnetv27_stage2_conv16_fwd    12.59
# resnetv27_stage2_batchnorm16_fwd 0.00
# resnetv27_stage2_activation16  0.00
# resnetv27_stage2_conv17_fwd    12.79
# resnetv27_stage2_batchnorm17_fwd 0.00
# resnetv27_stage2_activation17  0.00
# resnetv27_stage2_conv18_fwd    5.33
# resnetv27_stage2__plus5        2.19
# resnetv27_stage2_batchnorm18_fwd 0.61
# resnetv27_stage2_activation18  0.47
# resnetv27_stage2_conv19_fwd    5.74
# resnetv27_stage2_batchnorm19_fwd 0.00
# resnetv27_stage2_activation19  0.00
# resnetv27_stage2_conv20_fwd    20.98
# resnetv27_stage2_batchnorm20_fwd 0.00
# resnetv27_stage2_activation20  0.00
# resnetv27_stage2_conv21_fwd    15.84
# resnetv27_stage2__plus6        1.38
# resnetv27_stage2_batchnorm21_fwd 0.70
# resnetv27_stage2_activation21  0.92
# resnetv27_stage2_conv22_fwd    32.00
# resnetv27_stage2_batchnorm22_fwd 0.00
# resnetv27_stage2_activation22  0.00
# resnetv27_stage2_conv23_fwd    15.76
# resnetv27_stage2_batchnorm23_fwd 0.00
# resnetv27_stage2_activation23  0.00
# resnetv27_stage2_conv24_fwd    11.92
# resnetv27_stage2__plus7        1.53
# resnetv27_stage3_batchnorm0_fwd 0.00
# resnetv27_stage3_activation0   0.34
# resnetv27_stage3_conv0_fwd     13.16
# resnetv27_stage3_batchnorm1_fwd 0.00
# resnetv27_stage3_activation1   0.00
# resnetv27_stage3_conv1_fwd     14.87
# resnetv27_stage3_batchnorm2_fwd 0.00
# resnetv27_stage3_activation2   0.00
# resnetv27_stage3_conv2_fwd     13.85
# resnetv27_stage3_conv3_fwd     14.80
# resnetv27_stage3__plus0        0.51
# resnetv27_stage3_batchnorm3_fwd 0.67
# resnetv27_stage3_activation3   48.46
# resnetv27_stage3_conv4_fwd     6.29
# resnetv27_stage3_batchnorm4_fwd 0.00
# resnetv27_stage3_activation4   0.00
# resnetv27_stage3_conv5_fwd     12.48
# resnetv27_stage3_batchnorm5_fwd 0.00
# resnetv27_stage3_activation5   0.00
# resnetv27_stage3_conv6_fwd     5.26
# resnetv27_stage3__plus1        0.40
# resnetv27_stage3_batchnorm6_fwd 0.72
# resnetv27_stage3_activation6   1.24
# resnetv27_stage3_conv7_fwd     6.42
# resnetv27_stage3_batchnorm7_fwd 0.00
# resnetv27_stage3_activation7   0.00
# resnetv27_stage3_conv8_fwd     14.69
# resnetv27_stage3_batchnorm8_fwd 0.00
# resnetv27_stage3_activation8   0.00
# resnetv27_stage3_conv9_fwd     10.96
# resnetv27_stage3__plus2        9.30
# resnetv27_stage3_batchnorm9_fwd 0.69
# resnetv27_stage3_activation9   0.67
# resnetv27_stage3_conv10_fwd    17.70
# resnetv27_stage3_batchnorm10_fwd 0.00
# resnetv27_stage3_activation10  0.00
# resnetv27_stage3_conv11_fwd    33.11
# resnetv27_stage3_batchnorm11_fwd 0.00
# resnetv27_stage3_activation11  0.00
# resnetv27_stage3_conv12_fwd    9.62
# resnetv27_stage3__plus3        0.76
# resnetv27_stage3_batchnorm12_fwd 0.69
# resnetv27_stage3_activation12  0.41
# resnetv27_stage3_conv13_fwd    15.52
# resnetv27_stage3_batchnorm13_fwd 0.00
# resnetv27_stage3_activation13  0.00
# resnetv27_stage3_conv14_fwd    18.47
# resnetv27_stage3_batchnorm14_fwd 0.00
# resnetv27_stage3_activation14  0.00
# resnetv27_stage3_conv15_fwd    36.92
# resnetv27_stage3__plus4        0.82
# resnetv27_stage3_batchnorm15_fwd 0.99
# resnetv27_stage3_activation15  0.64
# resnetv27_stage3_conv16_fwd    9.50
# resnetv27_stage3_batchnorm16_fwd 0.00
# resnetv27_stage3_activation16  0.00
# resnetv27_stage3_conv17_fwd    17.92
# resnetv27_stage3_batchnorm17_fwd 0.00
# resnetv27_stage3_activation17  0.00
# resnetv27_stage3_conv18_fwd    7.26
# resnetv27_stage3__plus5        0.65
# resnetv27_stage3_batchnorm18_fwd 0.69
# resnetv27_stage3_activation18  0.26
# resnetv27_stage3_conv19_fwd    7.30
# resnetv27_stage3_batchnorm19_fwd 0.00
# resnetv27_stage3_activation19  0.00
# resnetv27_stage3_conv20_fwd    14.34
# resnetv27_stage3_batchnorm20_fwd 0.00
# resnetv27_stage3_activation20  0.00
# resnetv27_stage3_conv21_fwd    14.33
# resnetv27_stage3__plus6        1.83
# resnetv27_stage3_batchnorm21_fwd 0.61
# resnetv27_stage3_activation21  0.22
# resnetv27_stage3_conv22_fwd    47.37
# resnetv27_stage3_batchnorm22_fwd 0.00
# resnetv27_stage3_activation22  0.00
# resnetv27_stage3_conv23_fwd    19.42
# resnetv27_stage3_batchnorm23_fwd 0.00
# resnetv27_stage3_activation23  0.00
# resnetv27_stage3_conv24_fwd    6.28
# resnetv27_stage3__plus7        0.51
# resnetv27_stage3_batchnorm24_fwd 0.70
# resnetv27_stage3_activation24  0.55
# resnetv27_stage3_conv25_fwd    6.86
# resnetv27_stage3_batchnorm25_fwd 0.00
# resnetv27_stage3_activation25  0.00
# resnetv27_stage3_conv26_fwd    13.02
# resnetv27_stage3_batchnorm26_fwd 0.00
# resnetv27_stage3_activation26  0.00
# resnetv27_stage3_conv27_fwd    46.34
# resnetv27_stage3__plus8        0.83
# resnetv27_stage3_batchnorm27_fwd 0.58
# resnetv27_stage3_activation27  0.58
# resnetv27_stage3_conv28_fwd    16.66
# resnetv27_stage3_batchnorm28_fwd 0.00
# resnetv27_stage3_activation28  0.00
# resnetv27_stage3_conv29_fwd    17.35
# resnetv27_stage3_batchnorm29_fwd 0.00
# resnetv27_stage3_activation29  0.00
# resnetv27_stage3_conv30_fwd    16.28
# resnetv27_stage3__plus9        2.15
# resnetv27_stage3_batchnorm30_fwd 0.78
# resnetv27_stage3_activation30  0.58
# resnetv27_stage3_conv31_fwd    12.69
# resnetv27_stage3_batchnorm31_fwd 0.00
# resnetv27_stage3_activation31  0.00
# resnetv27_stage3_conv32_fwd    14.06
# resnetv27_stage3_batchnorm32_fwd 0.00
# resnetv27_stage3_activation32  0.00
# resnetv27_stage3_conv33_fwd    7.43
# resnetv27_stage3__plus10       0.73
# resnetv27_stage3_batchnorm33_fwd 2.87
# resnetv27_stage3_activation33  0.78
# resnetv27_stage3_conv34_fwd    18.27
# resnetv27_stage3_batchnorm34_fwd 0.00
# resnetv27_stage3_activation34  0.00
# resnetv27_stage3_conv35_fwd    36.41
# resnetv27_stage3_batchnorm35_fwd 0.00
# resnetv27_stage3_activation35  0.00
# resnetv27_stage3_conv36_fwd    7.06
# resnetv27_stage3__plus11       5.04
# resnetv27_stage3_batchnorm36_fwd 0.69
# resnetv27_stage3_activation36  0.74
# resnetv27_stage3_conv37_fwd    6.40
# resnetv27_stage3_batchnorm37_fwd 0.00
# resnetv27_stage3_activation37  0.00
# resnetv27_stage3_conv38_fwd    13.12
# resnetv27_stage3_batchnorm38_fwd 0.00
# resnetv27_stage3_activation38  0.00
# resnetv27_stage3_conv39_fwd    6.46
# resnetv27_stage3__plus12       1.13
# resnetv27_stage3_batchnorm39_fwd 0.58
# resnetv27_stage3_activation39  0.66
# resnetv27_stage3_conv40_fwd    44.33
# resnetv27_stage3_batchnorm40_fwd 0.00
# resnetv27_stage3_activation40  0.00
# resnetv27_stage3_conv41_fwd    21.39
# resnetv27_stage3_batchnorm41_fwd 0.00
# resnetv27_stage3_activation41  0.00
# resnetv27_stage3_conv42_fwd    8.57
# resnetv27_stage3__plus13       0.71
# resnetv27_stage3_batchnorm42_fwd 0.66
# resnetv27_stage3_activation42  0.69
# resnetv27_stage3_conv43_fwd    12.65
# resnetv27_stage3_batchnorm43_fwd 0.00
# resnetv27_stage3_activation43  0.00
# resnetv27_stage3_conv44_fwd    17.61
# resnetv27_stage3_batchnorm44_fwd 0.00
# resnetv27_stage3_activation44  0.00
# resnetv27_stage3_conv45_fwd    39.46
# resnetv27_stage3__plus14       1.13
# resnetv27_stage3_batchnorm45_fwd 0.77
# resnetv27_stage3_activation45  0.78
# resnetv27_stage3_conv46_fwd    17.63
# resnetv27_stage3_batchnorm46_fwd 0.00
# resnetv27_stage3_activation46  0.00
# resnetv27_stage3_conv47_fwd    12.70
# resnetv27_stage3_batchnorm47_fwd 0.00
# resnetv27_stage3_activation47  0.00
# resnetv27_stage3_conv48_fwd    6.13
# resnetv27_stage3__plus15       0.42
# resnetv27_stage3_batchnorm48_fwd 0.68
# resnetv27_stage3_activation48  0.23
# resnetv27_stage3_conv49_fwd    7.74
# resnetv27_stage3_batchnorm49_fwd 0.00
# resnetv27_stage3_activation49  0.00
# resnetv27_stage3_conv50_fwd    60.50
# resnetv27_stage3_batchnorm50_fwd 0.00
# resnetv27_stage3_activation50  0.00
# resnetv27_stage3_conv51_fwd    10.42
# resnetv27_stage3__plus16       2.52
# resnetv27_stage3_batchnorm51_fwd 0.65
# resnetv27_stage3_activation51  1.08
# resnetv27_stage3_conv52_fwd    6.16
# resnetv27_stage3_batchnorm52_fwd 0.00
# resnetv27_stage3_activation52  0.00
# resnetv27_stage3_conv53_fwd    13.78
# resnetv27_stage3_batchnorm53_fwd 0.00
# resnetv27_stage3_activation53  0.00
# resnetv27_stage3_conv54_fwd    6.72
# resnetv27_stage3__plus17       0.67
# resnetv27_stage3_batchnorm54_fwd 0.61
# resnetv27_stage3_activation54  0.30
# resnetv27_stage3_conv55_fwd    6.84
# resnetv27_stage3_batchnorm55_fwd 0.00
# resnetv27_stage3_activation55  0.00
# resnetv27_stage3_conv56_fwd    10.04
# resnetv27_stage3_batchnorm56_fwd 0.00
# resnetv27_stage3_activation56  0.00
# resnetv27_stage3_conv57_fwd    5.28
# resnetv27_stage3__plus18       0.37
# resnetv27_stage3_batchnorm57_fwd 0.71
# resnetv27_stage3_activation57  0.50
# resnetv27_stage3_conv58_fwd    12.83
# resnetv27_stage3_batchnorm58_fwd 0.00
# resnetv27_stage3_activation58  0.00
# resnetv27_stage3_conv59_fwd    11.26
# resnetv27_stage3_batchnorm59_fwd 0.00
# resnetv27_stage3_activation59  0.00
# resnetv27_stage3_conv60_fwd    52.21
# resnetv27_stage3__plus19       4.43
# resnetv27_stage3_batchnorm60_fwd 0.62
# resnetv27_stage3_activation60  0.71
# resnetv27_stage3_conv61_fwd    7.12
# resnetv27_stage3_batchnorm61_fwd 0.00
# resnetv27_stage3_activation61  0.00
# resnetv27_stage3_conv62_fwd    19.48
# resnetv27_stage3_batchnorm62_fwd 0.00
# resnetv27_stage3_activation62  0.00
# resnetv27_stage3_conv63_fwd    12.66
# resnetv27_stage3__plus20       3.99
# resnetv27_stage3_batchnorm63_fwd 3.36
# resnetv27_stage3_activation63  0.30
# resnetv27_stage3_conv64_fwd    43.74
# resnetv27_stage3_batchnorm64_fwd 0.00
# resnetv27_stage3_activation64  0.00
# resnetv27_stage3_conv65_fwd    23.75
# resnetv27_stage3_batchnorm65_fwd 0.00
# resnetv27_stage3_activation65  0.00
# resnetv27_stage3_conv66_fwd    8.61
# resnetv27_stage3__plus21       0.71
# resnetv27_stage3_batchnorm66_fwd 0.62
# resnetv27_stage3_activation66  0.32
# resnetv27_stage3_conv67_fwd    6.42
# resnetv27_stage3_batchnorm67_fwd 0.00
# resnetv27_stage3_activation67  0.00
# resnetv27_stage3_conv68_fwd    17.75
# resnetv27_stage3_batchnorm68_fwd 0.00
# resnetv27_stage3_activation68  0.00
# resnetv27_stage3_conv69_fwd    8.16
# resnetv27_stage3__plus22       0.40
# resnetv27_stage3_batchnorm69_fwd 0.62
# resnetv27_stage3_activation69  0.27
# resnetv27_stage3_conv70_fwd    6.50
# resnetv27_stage3_batchnorm70_fwd 0.00
# resnetv27_stage3_activation70  0.00
# resnetv27_stage3_conv71_fwd    13.50
# resnetv27_stage3_batchnorm71_fwd 0.00
# resnetv27_stage3_activation71  0.00
# resnetv27_stage3_conv72_fwd    7.84
# resnetv27_stage3__plus23       0.61
# resnetv27_stage3_batchnorm72_fwd 0.61
# resnetv27_stage3_activation72  0.27
# resnetv27_stage3_conv73_fwd    41.83
# resnetv27_stage3_batchnorm73_fwd 0.00
# resnetv27_stage3_activation73  0.00
# resnetv27_stage3_conv74_fwd    20.30
# resnetv27_stage3_batchnorm74_fwd 0.00
# resnetv27_stage3_activation74  0.00
# resnetv27_stage3_conv75_fwd    11.46
# resnetv27_stage3__plus24       3.64
# resnetv27_stage3_batchnorm75_fwd 0.57
# resnetv27_stage3_activation75  0.26
# resnetv27_stage3_conv76_fwd    41.58
# resnetv27_stage3_batchnorm76_fwd 0.00
# resnetv27_stage3_activation76  0.00
# resnetv27_stage3_conv77_fwd    22.41
# resnetv27_stage3_batchnorm77_fwd 0.00
# resnetv27_stage3_activation77  0.00
# resnetv27_stage3_conv78_fwd    5.85
# resnetv27_stage3__plus25       0.42
# resnetv27_stage3_batchnorm78_fwd 0.61
# resnetv27_stage3_activation78  0.27
# resnetv27_stage3_conv79_fwd    6.91
# resnetv27_stage3_batchnorm79_fwd 0.00
# resnetv27_stage3_activation79  0.00
# resnetv27_stage3_conv80_fwd    14.03
# resnetv27_stage3_batchnorm80_fwd 0.00
# resnetv27_stage3_activation80  0.00
# resnetv27_stage3_conv81_fwd    22.34
# resnetv27_stage3__plus26       25.03
# resnetv27_stage3_batchnorm81_fwd 0.71
# resnetv27_stage3_activation81  0.68
# resnetv27_stage3_conv82_fwd    16.32
# resnetv27_stage3_batchnorm82_fwd 0.00
# resnetv27_stage3_activation82  0.00
# resnetv27_stage3_conv83_fwd    12.48
# resnetv27_stage3_batchnorm83_fwd 0.00
# resnetv27_stage3_activation83  0.00
# resnetv27_stage3_conv84_fwd    4.87
# resnetv27_stage3__plus27       0.40
# resnetv27_stage3_batchnorm84_fwd 0.71
# resnetv27_stage3_activation84  0.30
# resnetv27_stage3_conv85_fwd    5.94
# resnetv27_stage3_batchnorm85_fwd 0.00
# resnetv27_stage3_activation85  0.00
# resnetv27_stage3_conv86_fwd    15.70
# resnetv27_stage3_batchnorm86_fwd 0.00
# resnetv27_stage3_activation86  0.00
# resnetv27_stage3_conv87_fwd    8.05
# resnetv27_stage3__plus28       0.72
# resnetv27_stage3_batchnorm87_fwd 0.57
# resnetv27_stage3_activation87  0.27
# resnetv27_stage3_conv88_fwd    6.59
# resnetv27_stage3_batchnorm88_fwd 0.00
# resnetv27_stage3_activation88  0.00
# resnetv27_stage3_conv89_fwd    33.38
# resnetv27_stage3_batchnorm89_fwd 0.00
# resnetv27_stage3_activation89  0.00
# resnetv27_stage3_conv90_fwd    10.90
# resnetv27_stage3__plus29       1.27
# resnetv27_stage3_batchnorm90_fwd 0.70
# resnetv27_stage3_activation90  0.80
# resnetv27_stage3_conv91_fwd    8.90
# resnetv27_stage3_batchnorm91_fwd 0.00
# resnetv27_stage3_activation91  0.00
# resnetv27_stage3_conv92_fwd    31.60
# resnetv27_stage3_batchnorm92_fwd 0.00
# resnetv27_stage3_activation92  0.00
# resnetv27_stage3_conv93_fwd    6.68
# resnetv27_stage3__plus30       0.46
# resnetv27_stage3_batchnorm93_fwd 0.62
# resnetv27_stage3_activation93  0.29
# resnetv27_stage3_conv94_fwd    7.90
# resnetv27_stage3_batchnorm94_fwd 0.00
# resnetv27_stage3_activation94  0.00
# resnetv27_stage3_conv95_fwd    14.84
# resnetv27_stage3_batchnorm95_fwd 0.00
# resnetv27_stage3_activation95  0.00
# resnetv27_stage3_conv96_fwd    6.76
# resnetv27_stage3__plus31       0.77
# resnetv27_stage3_batchnorm96_fwd 0.66
# resnetv27_stage3_activation96  0.35
# resnetv27_stage3_conv97_fwd    18.59
# resnetv27_stage3_batchnorm97_fwd 0.00
# resnetv27_stage3_activation97  0.00
# resnetv27_stage3_conv98_fwd    24.80
# resnetv27_stage3_batchnorm98_fwd 0.00
# resnetv27_stage3_activation98  0.00
# resnetv27_stage3_conv99_fwd    27.35
# resnetv27_stage3__plus32       1.11
# resnetv27_stage3_batchnorm99_fwd 0.76
# resnetv27_stage3_activation99  0.82
# resnetv27_stage3_conv100_fwd   12.06
# resnetv27_stage3_batchnorm100_fwd 0.00
# resnetv27_stage3_activation100 0.00
# resnetv27_stage3_conv101_fwd   13.76
# resnetv27_stage3_batchnorm101_fwd 0.00
# resnetv27_stage3_activation101 0.00
# resnetv27_stage3_conv102_fwd   5.84
# resnetv27_stage3__plus33       0.49
# resnetv27_stage3_batchnorm102_fwd 0.58
# resnetv27_stage3_activation102 0.28
# resnetv27_stage3_conv103_fwd   6.83
# resnetv27_stage3_batchnorm103_fwd 0.00
# resnetv27_stage3_activation103 0.00
# resnetv27_stage3_conv104_fwd   10.89
# resnetv27_stage3_batchnorm104_fwd 0.00
# resnetv27_stage3_activation104 0.00
# resnetv27_stage3_conv105_fwd   6.71
# resnetv27_stage3__plus34       2.55
# resnetv27_stage3_batchnorm105_fwd 0.78
# resnetv27_stage3_activation105 0.84
# resnetv27_stage3_conv106_fwd   16.15
# resnetv27_stage3_batchnorm106_fwd 0.00
# resnetv27_stage3_activation106 0.00
# resnetv27_stage3_conv107_fwd   19.12
# resnetv27_stage3_batchnorm107_fwd 0.00
# resnetv27_stage3_activation107 0.00
# resnetv27_stage3_conv108_fwd   17.65
# resnetv27_stage3__plus35       0.69
# resnetv27_stage4_batchnorm0_fwd 0.00
# resnetv27_stage4_activation0   0.43
# resnetv27_stage4_conv0_fwd     28.49
# resnetv27_stage4_batchnorm1_fwd 0.00
# resnetv27_stage4_activation1   0.00
# resnetv27_stage4_conv1_fwd     21.58
# resnetv27_stage4_batchnorm2_fwd 0.00
# resnetv27_stage4_activation2   0.00
# resnetv27_stage4_conv2_fwd     9.30
# resnetv27_stage4_conv3_fwd     20.72
# resnetv27_stage4__plus0        0.28
# resnetv27_stage4_batchnorm3_fwd 0.96
# resnetv27_stage4_activation3   0.50
# resnetv27_stage4_conv4_fwd     13.32
# resnetv27_stage4_batchnorm4_fwd 0.00
# resnetv27_stage4_activation4   0.00
# resnetv27_stage4_conv5_fwd     21.19
# resnetv27_stage4_batchnorm5_fwd 0.00
# resnetv27_stage4_activation5   0.00
# resnetv27_stage4_conv6_fwd     48.33
# resnetv27_stage4__plus1        0.29
# resnetv27_stage4_batchnorm6_fwd 1.01
# resnetv27_stage4_activation6   0.65
# resnetv27_stage4_conv7_fwd     23.96
# resnetv27_stage4_batchnorm7_fwd 0.00
# resnetv27_stage4_activation7   0.00
# resnetv27_stage4_conv8_fwd     22.92
# resnetv27_stage4_batchnorm8_fwd 0.00
# resnetv27_stage4_activation8   0.00
# resnetv27_stage4_conv9_fwd     12.64
# resnetv27_stage4__plus2        0.60
# resnetv27_batchnorm2_fwd       0.00
# resnetv27_relu1_fwd            0.45
# resnetv27_pool1_fwd            0.29
# resnetv27_flatten0_reshape0    0.01
# resnetv27_dense0_fwd           1.51
