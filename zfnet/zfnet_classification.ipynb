# %%
import matplotlib.pyplot as plt
import numpy as np
import time
import cv2

# %% [markdown]
# ## ZFNet Classification

# %%
def zfnet_classification(image_path, net, mean_val, class_names, 
                         swap_channels=False):
    image = cv2.imread(image_path)
    if isinstance(mean_val, np.ndarray):
        tensor = cv2.dnn.blobFromImage(image, 1.0, (224, 224),
                                       1.0, False)
        tensor -= mean_val
    else:
        tensor = cv2.dnn.blobFromImage(image, 1.0, (224, 224),
                                       mean_val, swap_channels)
    
    net.setInput(tensor)
    start = time.time()
    prob = net.forward()
    prob = prob.flatten()
    end = time.time()
    
    # show timing information on ZFNet
    print("Forward Time: ZFNet took {:.6f} seconds.".format(end - start))
    
    r = 1
    for i in np.argsort(prob)[-5:]:
        txt = "Label: {}, {:.2f}%".format(class_names[i], prob[i] * 100)
        cv2.putText(image, txt, (10, image.shape[0] - r*30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2);
        r += 1
    
    # show the image after classifying
    plt.figure(figsize=(15, 12))
    plt.imshow(image[:, :, [2, 1, 0]])
    plt.axis('off')
    plt.grid(False)
    plt.show()

# %%
class_names_path = "./model/synset_words.txt"
with open(class_names_path) as f:
    class_names = [' '.join(l.split(' ')[1: ]).rstrip() for l in f.readlines()]

# %%
model_path = "./model/model.onnx"
zfnet = cv2.dnn.readNetFromONNX(model_path)

# %%
image_path = "../../../datasets/temple.jpg"
zfnet_classification(image_path, zfnet, (104, 117, 123), class_names)
# Out:
# Forward Time: ZFNet took 0.533625 seconds.

# %%
image_path = "../../../datasets/subway.jpg"
zfnet_classification(image_path, zfnet, (104, 117, 123), class_names)
# Out:
# Forward Time: ZFNet took 0.399023 seconds.

# %%
image_path = "../../../datasets/pandas.jpg"
zfnet_classification(image_path, zfnet, (104, 117, 123), class_names)
# Out:
# Forward Time: ZFNet took 0.388022 seconds.
