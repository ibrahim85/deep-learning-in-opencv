# %% [markdown]
# loading pretrained models from 3 very popular frameworks: `Caffe`, `Torch`, and `TensorFlow`

# %%
import numpy as np
import cv2

# %% [markdown]
# ### From Caffe

# %%
net_caffe = cv2.dnn.readNetFromCaffe("../../pretrained-models/bvlc_googlenet.prototxt",
                                     "../../pretrained-models/bvlc_googlenet.caffemodel")
net_caffe.getLayerNames()
# Out:
# ['conv1/7x7_s2',
#  'conv1/relu_7x7',
#  'pool1/3x3_s2',
#  'pool1/norm1',
#  'conv2/3x3_reduce',
#  'conv2/relu_3x3_reduce',
#  'conv2/3x3',
#  'conv2/relu_3x3',
#  'conv2/norm2',
#  'pool2/3x3_s2',
#  'inception_3a/1x1',
#  'inception_3a/relu_1x1',
#  'inception_3a/3x3_reduce',
#  'inception_3a/relu_3x3_reduce',
#  'inception_3a/3x3',
#  'inception_3a/relu_3x3',
#  'inception_3a/5x5_reduce',
#  'inception_3a/relu_5x5_reduce',
#  'inception_3a/5x5',
#  'inception_3a/relu_5x5',
#  'inception_3a/pool',
#  'inception_3a/pool_proj',
#  'inception_3a/relu_pool_proj',
#  'inception_3a/output',
#  'inception_3b/1x1',
#  'inception_3b/relu_1x1',
#  'inception_3b/3x3_reduce',
#  'inception_3b/relu_3x3_reduce',
#  'inception_3b/3x3',
#  'inception_3b/relu_3x3',
#  'inception_3b/5x5_reduce',
#  'inception_3b/relu_5x5_reduce',
#  'inception_3b/5x5',
#  'inception_3b/relu_5x5',
#  'inception_3b/pool',
#  'inception_3b/pool_proj',
#  'inception_3b/relu_pool_proj',
#  'inception_3b/output',
# ...

# %% [markdown]
# ### From PyTorch

# %%
net_torch = cv2.dnn.readNetFromTorch("../../pretrained-models/torch_enet_model.net")
net_caffe.getLayerNames()
# Out:
# ['conv1/7x7_s2',
#  'conv1/relu_7x7',
#  'pool1/3x3_s2',
#  'pool1/norm1',
#  'conv2/3x3_reduce',
#  'conv2/relu_3x3_reduce',
#  'conv2/3x3',
#  'conv2/relu_3x3',
#  'conv2/norm2',
#  'pool2/3x3_s2',
#  'inception_3a/1x1',
#  'inception_3a/relu_1x1',
#  'inception_3a/3x3_reduce',
#  'inception_3a/relu_3x3_reduce',
#  'inception_3a/3x3',
#  'inception_3a/relu_3x3',
#  'inception_3a/5x5_reduce',
#  'inception_3a/relu_5x5_reduce',
#  'inception_3a/5x5',
#  'inception_3a/relu_5x5',
#  'inception_3a/pool',
#  'inception_3a/pool_proj',
#  'inception_3a/relu_pool_proj',
#  'inception_3a/output',
#  'inception_3b/1x1',
#  'inception_3b/relu_1x1',
#  'inception_3b/3x3_reduce',
#  'inception_3b/relu_3x3_reduce',
#  'inception_3b/3x3',
#  'inception_3b/relu_3x3',
#  'inception_3b/5x5_reduce',
#  'inception_3b/relu_5x5_reduce',
#  'inception_3b/5x5',
#  'inception_3b/relu_5x5',
#  'inception_3b/pool',
#  'inception_3b/pool_proj',
#  'inception_3b/relu_pool_proj',
#  'inception_3b/output',
# ...

# %% [markdown]
# ### From Tensorflow

# %%
net_tensorflow = cv2.dnn.readNetFromTensorflow("../../pretrained-models/tensorflow_inception_graph.pb")
net_tensorflow.getLayerNames()
# Out:
# ['conv2d0_pre_relu/conv',
#  'conv2d0',
#  'maxpool0',
#  'localresponsenorm0',
#  'conv2d1_pre_relu/conv',
#  'conv2d1',
#  'conv2d2_pre_relu/conv',
#  'conv2d2',
#  'localresponsenorm1',
#  'maxpool1',
#  'mixed3a_pool',
#  'mixed3a_pool_reduce_pre_relu/conv',
#  'mixed3a_pool_reduce',
#  'mixed3a_5x5_bottleneck_pre_relu/conv',
#  'mixed3a_5x5_bottleneck',
#  'mixed3a_5x5_pre_relu/conv',
#  'mixed3a_5x5',
#  'mixed3a_3x3_bottleneck_pre_relu/conv',
#  'mixed3a_3x3_bottleneck',
#  'mixed3a_3x3_pre_relu/conv',
#  'mixed3a_3x3',
#  'mixed3a_1x1_pre_relu/conv',
#  'mixed3a_1x1',
#  'mixed3a',
#  'mixed3b_pool',
#  'mixed3b_pool_reduce_pre_relu/conv',
#  'mixed3b_pool_reduce',
#  'mixed3b_5x5_bottleneck_pre_relu/conv',
#  'mixed3b_5x5_bottleneck',
#  'mixed3b_5x5_pre_relu/conv',
#  'mixed3b_5x5',
#  'mixed3b_3x3_bottleneck_pre_relu/conv',
#  'mixed3b_3x3_bottleneck',
#  'mixed3b_3x3_pre_relu/conv',
#  'mixed3b_3x3',
#  'mixed3b_1x1_pre_relu/conv',
#  'mixed3b_1x1',
#  'mixed3b',
# ...
